# %% [markdown]
# # **Machine Learning Model for Predicting Term Deposit Made by New Customer**
#
# In this notebook, The goal is to explore and implement the best machine learning models for Predicting Term Deposit Made by New Customer using the Bank Marketing Campaign Dataset. This project is part of Purwadhika's Digital Talent Incubator (DTI) Data Science program, specifically Capstone 3 Machine Learning.

# %% [markdown]
# # **Table Of Content**
#
#
# 1. Business Problem Understanding
#     <br> 1.1. Context
#     <br> 1.2. Problem Statements
#     <br> 1.3. Objectives
#     <br> 1.4. Analytical Approach
#     <br> 1.5. Evaluation Metric
# 2. Data Exploration
#     <br> 2.1. Feature Details
#     <br> 2.2. Descriptive Analysis
# 3. Data Preprocessing
#     <br> 3.1. Missing Values
#     <br> 3.2. Data Cleaning
#     <br> 3.3. Outliers
# 4. Exploratory Data Analysis (EDA)
# 5. Feature Engineering
#     <br> 5.1. Data Transformation
#     <br> 5.2. Importing Additional Library
#     <br> 5.3. Define Features, Target, and Encoder
#     <br> 5.4. Normalization
#     <br> 5.5. Data Splitting
# 6. Model Selection and Training
#     <br> 6.1. Defining Models for Benchmarking
#     <br> 6.2. Finding the Best Model
#
# 7. Model Evaluation
#     <br> 7.1. Implementing of the Best Results
#     <br> 7.2. Interpretation of the Results
#
# 8. Cost Benefit Analysis
#     <br> 8.1. Cost-Benefit Analysis for Term Deposit Subscription Model
#     <br> 8.2. Key Findings
#     <br> 8.3. Conclusion
#     <br> 8.4  Recommendations

# %% [markdown]
# # **1. Business Problem Understanding**

# %% [markdown]
# ## **1.1. Context**

# %% [markdown]
# The types of financial products used by the public are more varied. One financial product that is well-known to the public is term deposits. The term deposit mechanism is that a customer deposits a sum of money at a bank or a financial institution, and the money can only be withdrawn after a certain period of time. As compensation, customers will be given a fixed interest according to the nominal amount of money deposited.
#
# Nevertheless, as business entities with financial products and respective customers, banks still have to compete to not lose customers. One of the ways to acquire new customers is by conducting a marketing campaign.
#
# However, marketing campaign must be designed as efficient as possible in order to gain profit, which could help the bank to survive, compete with the competitors, and even expand their business.
#
# Banks need deposits to fund their lending activities, manage liquidity, and maintain operational efficiency. Deposits provide a low-cost source of capital that banks use to create credit, earn interest income, and meet regulatory requirements. They also help establish trust and stability, attract business, and generate additional revenue through fees. Overall, deposits are essential for a bank's financial health and its ability to support economic growth. Term deposit subscriptions directly impact the bank's revenue and financial stability, as they are a source of funds that the bank can use for lending and investments.
#
# Predicting term deposit subscriptions allows the bank to focus its marketing efforts on the most promising customer, thus improving the return on investment (ROI) of marketing campaigns. By identifying customers who are likely to subscribe, the bank can tailor its marketing messages and offers, enhancing customer satisfaction and loyalty. Customers who subscribe to term deposits are often more valuable in the long run, as they tend to have a higher lifetime value through continued engagement with the bank's products and services.
#
# Machine Learning can be important for identifying the customer who are likely to subscribe, by analyzing the data of the customer, to understand the customer behavior, and because of that, the machine learning models able to predict customer that have potential to make a term deposit. It is important to accurately allocate the budget for market campaign, by knowing the potential customer. This capability allows banks to focus their marketing efforts on individuals with a higher tendency to subscribe, thereby increasing the effectiveness of their campaigns.
#
# Reference:
# - Agarwal, S., & Kim, K. (2023). The transformation of nominally immediate-maturity, highly liquid deposits and its role in banks' economic function(Working Paper No. 2315). Federal Reserve Bank of Dallas. https://www.dallasfed.org/-/media/documents/research/papers/2023/wp2315.pdf
# <br>
# - https://www.financestrategists.com/banking/bank-account/bank-account-deposits/
# - https://www.investopedia.com/ask/answers/032315/what-banking-sector.asp

# %% [markdown]
# ## **1.2. Problem Statements**

# %% [markdown]
# 1. Which features are most influential? Determine which customer attributes (e.g., age, job, balance, contact method) are most strongly associated with the likelihood of subscribing to a term deposit.
# 2. How can this information be used? Use insights to create marketing strategies, such as targeting specific age groups or professions that are more likely to convert.

# %% [markdown]
# ## **1.3. Objectives**

# %% [markdown]
# Based on the problem statements, the banks needs to:
#
# 1. Identify which features (attributes) most significantly influence whether a customer will subscribe to a term deposit.
# 2. Develop machine learning models as predictive tools to detect customers who are likely to subscribe to a term deposit.
# 3. Use the trained model to predict subscription likelihood for new customer data

# %% [markdown]
# ## **1.4. Analytical Approach**

# %% [markdown]
# Performing EDA (Exploratory Data Analysis) is crucial to understand and prepare the data for modeling. By performing EDA, better understanding about the data can be gained, pattern and its relationship can be analyzed, detecting anomalies and outliers that can skew the results, and assessing the data quality. As a result, the most suitable models can be developed.

# %% [markdown]
# ## **1.5. Evaluation Metric**

# %% [markdown]
# The evaluation metric that will be used for the Model will be:
# 1. Accuracy
# Accuracy measures the proportion of total correct predictions (both subscribers and non-subscribers) out of all predictions made. . It gives a general idea of how well the model is performing overall in predicting whether a customer will subscribe to a term deposit.
# 2. Precision
# "It measures the proportion of actual subscribers among all customers predicted to subscribe. It is useful for minimizing the targeting of customers who are not actually interested. Precision helps to ensure when the model predicts a customer will subscribe, they are likely to do so."
#
# 3. Recall
# Recall measures the proportion of actual subscribers that the model successfully identifies. It is crucial to ensure that most of the customers who are actually interested in subscribing are captured by the model.
# 4. F1-Score
# The F1-score is a balanced measure that combines precision and recall. Useful to balance between capturing as many actual subscribers as possible (recall) and ensuring that the customers predicted to subscribe are indeed likely to do so (precision).
# 5. Confusion Matrix
# The confusion matrix provides a detailed view of prediction performance, showing how many subscribers were correctly identified (True Positives), how many non-subscribers were incorrectly predicted as subscribers (False Positives), and how many subscribers were missed (False Negatives). It helps in understanding the model’s errors in detail.

# %% [markdown]
# # **2. Data Exploration**

# %% [markdown]
# The dataset consists of:
# 1. Customer profile such as customer age, job, balance, housing and loan
# 2. Marketing Data such as contact communication type, last contact, number of contacts during the campaign, Number of days after the client was contacted from the previous campaign. Outcome of the previous marketing campaign, and Whether the customer deposits or not.

# %% [markdown]
# # **2.1. Feature Details**

# %% [markdown]
# | **Attribute** |	**Data Type**	| **Description**|
# | ---------------|------------------|--------------------------------------------------------------|
# |age	| int64	 | Age of the customer|
# |job	| object |	Job role of the customer|
# |balance|	int64 |	Account balance of the customer |
# |housing|	object |	Whether the customer has a housing loan (yes/no)|
# |loan	| object| Whether the customer has a personal loan (yes/no) |
# |contact |	object |	Type of communication used to contact the customer|
# |month | object	| Last contact month of the year |
# |campaign	| int64 |	Number of contacts performed during this campaign|
# |pdays |int64 |	Number of days since the client was last contacted from a previous campaign (999 means client was not previously contacted)|
# |poutcome | object	| Outcome of the previous marketing campaign|
# |deposit |	object	| Whether the customer subscribed to a term deposit (yes/no)|

# %% [markdown]
# ### Importing Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import missingno as msn

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Exploring the Dataset

# %%
bank_df = pd.read_csv('data_bank_marketing_campaign.csv')
bank_df
# Out:
#       age            job  balance housing loan    contact month  campaign  \
# 0      55         admin.     1662      no   no   cellular   jun         2
# 1      39  self-employed    -3058     yes  yes   cellular   apr         3
# 2      51         admin.     3025      no   no   cellular   may         1
# 3      38       services      -87     yes   no   cellular   may         1
# 4      36      housemaid      205     yes   no  telephone   nov         4
# ...   ...            ...      ...     ...  ...        ...   ...       ...
# 7808   62      housemaid        2      no   no   cellular   nov         1
# 7809   48      housemaid     5473      no   no   cellular   feb         2
# 7810   36        unknown      179      no   no   cellular   aug         8
# 7811   31         admin.       54     yes   no   cellular   nov         1
# 7812   60        retired     1588      no   no   cellular   oct         1
#
#       pdays poutcome deposit
# 0        -1  unknown     yes
# ...

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7813 entries, 0 to 7812
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       7813 non-null   int64
#  1   job       7813 non-null   object
#  2   balance   7813 non-null   int64
#  3   housing   7813 non-null   object
#  4   loan      7813 non-null   object
#  5   contact   7813 non-null   object
#  6   month     7813 non-null   object
#  7   campaign  7813 non-null   int64
#  8   pdays     7813 non-null   int64
#  9   poutcome  7813 non-null   object
#  10  deposit   7813 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 671.6+ KB

# %% [markdown]
# # **2.2. Descriptive Analysis**

# %% [markdown]
# Descriptive analysis performed to identify the data type, nulls value in the dataset, and outliers.

# %%
bank_df.describe().T
# Out:
#            count         mean          std     min    25%    50%     75%  \
# age       7813.0    41.257264    11.919710    18.0   32.0   39.0    49.0
# balance   7813.0  1512.448611  3089.291831 -6847.0  127.0  549.0  1684.0
# campaign  7813.0     2.519775     2.727001     1.0    1.0    2.0     3.0
# pdays     7813.0    51.408550   108.072739    -1.0   -1.0   -1.0    40.0
#
#               max
# age          95.0
# balance   66653.0
# campaign     63.0
# pdays       854.0

# %%
bank_df.describe(include=object).T
# Out:
#          count unique         top  freq
# job       7813     12  management  1792
# housing   7813      2          no  4140
# loan      7813      2          no  6789
# contact   7813      3    cellular  5628
# month     7813     12         may  1976
# poutcome  7813      4     unknown  5819
# deposit   7813      2          no  4081

# %% [markdown]
# For easier readability, the data of the customer age transformed into age range, so that the proportion of the customer age can be read easier.

# %%
bins = [18, 25, 35, 45, 55, float('inf')]
labels = ['18-25', '26-35', '36-45', '46-55', '56+']
bank_df['age_range'] = pd.cut(bank_df['age'], bins=bins, labels=labels, right=False)

# Group by age_range and job to see the deposit status
age_range_job_deposit = bank_df.groupby(['age_range', 'job', 'deposit']).size().reset_index(name='count')

# Calculate total counts for each combination of age_range and job
total_counts = bank_df.groupby(['age_range', 'job']).size().reset_index(name='total_count')

# Merge the counts with the original grouped data
merged_data = pd.merge(age_range_job_deposit, total_counts, on=['age_range', 'job'])

# Sort by total count in descending order
sorted_data = merged_data.sort_values(by='total_count', ascending=False)

print("Sorted Deposits by Age Range and Job Based on Highest Count:")
print(sorted_data)
# Out:
# Sorted Deposits by Age Range and Job Based on Highest Count:
#     age_range         job deposit  count  total_count
# 33      26-35  management     yes    351          633
# 32      26-35  management      no    282          633
# 56      36-45  management      no    312          595
# 57      36-45  management     yes    283          595
# 107       56+     retired     yes    345          488
# ..        ...         ...     ...    ...          ...
# 10      18-25     retired      no      0            0
# 35      26-35     retired     yes      0            0
# 22      18-25     unknown      no      0            0
# 23      18-25     unknown     yes      0            0
# 11      18-25     retired     yes      0            0
#
# [120 rows x 5 columns]

# %% [markdown]
# # **3. Data Preprocessing**

# %% [markdown]
# Data preprocessing process include identifying  missing values, duplicate, and outliers. This process also includes data cleaning.

# %% [markdown]
# ## **3.1. Missing Values**

# %%
bank_df.isna().sum()
# Out:
# age          0
# job          0
# balance      0
# housing      0
# loan         0
# contact      0
# month        0
# campaign     0
# pdays        0
# poutcome     0
# deposit      0
# age_range    0
# dtype: int64

# %% [markdown]
# This results shows there are no missing values inside the dataset

# %% [markdown]
# ## **3.2. Data Cleaning**

# %%
# check for duplicates
print(f'Duplicated data: {bank_df.duplicated().sum()}')
print(f'Duplicated data percentage: {bank_df.duplicated().sum()/len(bank_df)*100:.2f}%')
# Out:
# Duplicated data: 8
# Duplicated data percentage: 0.10%

# %% [markdown]
# Here, it shown that there are duplicated data. Although  there are no further information about the customer identification number, its unclear whether these are unintended or not (from the possibility of multiple transactions from the same customer). However, to ensure the quality and accuracy of the analysis, it is better to remove it since it helps to avoid any potential biases that might be introduced by these duplicate entries.

# %%
# drop duplicates
bank_df.drop_duplicates(keep='last', inplace=True, ignore_index=True)

# %% [markdown]
# ## **3.3. Outliers**

# %% [markdown]
# Normality test performed so that the outliers can be handled appropriately.

# %%
import scipy.stats as stats
# List of numerical columns to analyze
numerical_columns = ['age', 'balance', 'campaign', 'pdays']

# Function to plot histogram and Q-Q plot 
def plot_normality(bank_df, column):
    # Histogram
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.hist(bank_df[column], bins=30, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    
    # Q-Q Plot
    plt.subplot(1, 2, 2)
    stats.probplot(bank_df[column], dist="norm", plot=plt)
    plt.title(f'Q-Q Plot of {column}')
    
    plt.tight_layout()
    plt.show()

# Apply the function to each numerical column
for col in numerical_columns:
    plot_normality(bank_df, col)

# Statistical Normality Tests
for col in numerical_columns:
    # Shapiro-Wilk Test
    stat, p_value = stats.shapiro(bank_df[col].dropna())
    print(f'Shapiro-Wilk Test p-value for {col}: {p_value}')
    
    # Kolmogorov-Smirnov Test
    stat, p_value = stats.kstest(bank_df[col].dropna(), 'norm', args=(bank_df[col].mean(), bank_df[col].std()))
    print(f'Kolmogorov-Smirnov Test p-value for {col}: {p_value}')
# Out:
# Shapiro-Wilk Test p-value for age: 0.0
# Kolmogorov-Smirnov Test p-value for age: 2.9883227229082926e-73
# Shapiro-Wilk Test p-value for balance: 0.0
# Kolmogorov-Smirnov Test p-value for balance: 0.0
# Shapiro-Wilk Test p-value for campaign: 0.0
# Kolmogorov-Smirnov Test p-value for campaign: 0.0
# Shapiro-Wilk Test p-value for pdays: 0.0
# Kolmogorov-Smirnov Test p-value for pdays: 0.0

# %% [markdown]
# From the graphic and the results, indicates that the data is not normally distributed. The numerical column such as the age, balance, number of contacts performed during this campaign and for this client, number of days after the client was contacted from the previous campaign show it is right-skewed distribution. This distribution could affect the the machine learning in terms of learning patterns

# %%
# Function to calculate outliers using IQR
def calculate_outliers(bank_df):
    outlier_counts = {}
    for column in bank_df.select_dtypes(include=['int64', 'float64']).columns:
        Q1 = bank_df[column].quantile(0.25)
        Q3 = bank_df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = bank_df[(bank_df[column] < lower_bound) | (bank_df[column] > upper_bound)]
        outlier_counts[column] = len(outliers)
    return outlier_counts

# Calculate outliers
outlier_counts = calculate_outliers(bank_df)

# Convert to Series for better readability
outlier_counts_series = pd.Series(outlier_counts, name='Outlier Counts')
print(outlier_counts_series)
# Out:
# age          121
# balance      736
# campaign     429
# pdays       1432
# Name: Outlier Counts, dtype: int64

# %%
# To inspect 
def inspect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# Inspect outliers for each numerical column
numerical_columns = bank_df.select_dtypes(include=['int64', 'float64']).columns
outliers_dict = {col: inspect_outliers(bank_df, col) for col in numerical_columns}

# Print outlier values
for col, outliers in outliers_dict.items():
    print(f"\nOutliers in column '{col}':")
    print(outliers[col])
# Out:
# Outliers in column 'age':
# 68      79
# 155     82
# 212     76
# 320     76
# 396     76
#         ..
# 7427    79
# 7603    75
# 7666    75
# 7674    75
# 7716    77
# Name: age, Length: 121, dtype: int64
#
# Outliers in column 'balance':
# 1       -3058
# 6        4803
# 14       4808
# 21       4929
# 36       6651
#         ...
# 7791     5381
# 7793     4108
# 7794    12067
# 7798    13901
# 7801     5473
# Name: balance, Length: 736, dtype: int64
#
# Outliers in column 'campaign':
# 50       7
# 67      30
# 101      8
# 113      9
# 184      8
#         ..
# 7756     8
# 7778     8
# 7782     7
# 7787     9
# 7802     8
# Name: campaign, Length: 429, dtype: int64
#
# Outliers in column 'pdays':
# 2       352
# 15      186
# 18      263
# 20      355
# 32      294
#        ...
# 7774    422
# 7785    251
# 7794    191
# 7797    155
# 7801    184
# Name: pdays, Length: 1432, dtype: int64

# %% [markdown]
# Lets investigate the outliers further using histogram

# %%
def plot_histogram_with_outliers(df, column, outliers):
    plt.figure(figsize=(10, 6))
    plt.hist(df[column], bins=30, alpha=0.5, label='All data')
    plt.hist(outliers[column], bins=30, alpha=0.5, label='Outliers', color='red')
    plt.title(f'Histogram of {column} with Outliers Highlighted')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

for col in numerical_columns:
    plot_histogram_with_outliers(bank_df, col, outliers_dict[col])

# %%
# Filter dataframe to get customers with negative balance and who made a deposit
negative_balance_with_deposit = bank_df[(bank_df['balance'] < 0) & (bank_df['deposit'] == 'yes')]
pdays_exceeding_100_and_deposit = bank_df[(bank_df['pdays'] > 100) & (bank_df['deposit'] == 'yes')]

# Convert the relevant columns to a Series for better readability
outliers_series = pd.Series({
    'Customers with negative balance who made a deposit': negative_balance_with_deposit.shape[0]
})

# Display the series
print("Possible Outliers:")
print(outliers_series)

# For detailed view, convert the dataframe of outliers to Series of relevant details
outliers_details_series = negative_balance_with_deposit[['balance', 'deposit']].reset_index(drop=True)
# Out:
# Possible Outliers:
# Customers with negative balance who made a deposit    140
# dtype: int64

# %%
campaign_exceeding_10_and_deposit = bank_df[(bank_df['campaign'] > 10) & (bank_df['deposit'] == 'yes')]
campaign_exceeding_10_and_deposit
# Out:
#       age            job  balance housing loan    contact month  campaign  \
# 193    43    blue-collar      184      no  yes   cellular   jul        11
# 196    29    blue-collar      260     yes   no    unknown   jun        14
# 346    49       services     1314      no   no   cellular   aug        14
# 773    32   entrepreneur      762      no   no   cellular   jul        11
# 900    60        unknown    17297      no   no   cellular   aug        11
# 1394   30         admin.      377     yes   no    unknown   jun        15
# 1767   37     technician     1435      no   no   cellular   aug        16
# 3013   31     management      792      no   no   cellular   aug        14
# 3121   28        student        0      no   no   cellular   feb        20
# 3218   27       services        0     yes   no   cellular   jul        13
# 3283   30       services       48     yes   no   cellular   jul        13
# 3364   95        retired     2282      no   no  telephone   apr        17
# ...

# %%
# IQR method
Q1 = bank_df['pdays'].quantile(0.25)
Q3 = bank_df['pdays'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_iqr = bank_df[(bank_df['pdays'] < lower_bound) | (bank_df['pdays'] > upper_bound)]

print("Outliers based on IQR:")
print(outliers_iqr)
# Out:
# Outliers based on IQR:
#       age         job  balance housing loan    contact month  campaign  pdays  \
# 2      51      admin.     3025      no   no   cellular   may         1    352
# 15     38  technician       88      no   no   cellular   nov         2    186
# 18     31  technician      863     yes   no   cellular   feb         1    263
# 20     48    services     2597     yes   no   cellular   may         2    355
# 32     33  technician      348     yes   no   cellular   may         2    294
# ...   ...         ...      ...     ...  ...        ...   ...       ...    ...
# 7774   59  technician      116      no   no   cellular   aug         4    422
# 7785   60  technician     4243     yes   no   cellular   feb         1    251
# 7794   63     retired    12067      no   no  telephone   apr         1    191
# 7797   47  management      159      no   no  telephone   oct         3    155
# 7801   48   housemaid     5473      no   no   cellular   feb         2    184
#
# ...

# %% [markdown]
# - From the histogram, in the age column, although it considered as an outliers, it shown that in the dataset, there are customer that is old (for instance 77 years old) which is still possible to happen, so these data will not be treated as outliers
# - There are no further information whether its possible to subscribe for a term deposit when the balance is negative. Therefore, the customer who subscribed but have negative balance will be treated as outliers. Assumably, the data of the customer who subscribed but have negative balance occurred due to the error in inputting the data, therefore, these value will be converted into its absolute value to obtain positive number.
# - The PDays is the number of days after the client was contacted from the previous campaign. It is understandable to some extend, because to make deposit is completely depends on the customer interest, however it is not make sense if the customer subscribed after 100 days of the campaign, especially the contact made only 1 time. Even if it happens, it shows the campaign is not successful, but this outliers will be leave as it is because we will bind it into data range later.
# - There are pdays that have negative values, this will be treated as outliers because we want to measure how successfull is the marketing campaign. And also, it might be occurred because of error in data input.

# %%
# Handling Outliers in Balance Column
df = bank_df.copy()

df.loc[(df['balance'] < 0) & (df['deposit'] == 'yes'), 'balance'] = df['balance'].abs()
# To verify
negative_balance_with_deposit = df[(df['balance'] < 0) & (df['deposit'] == 'yes')]
pdays_exceeding_100_and_deposit = df[(df['pdays'] > 100) & (df['deposit'] == 'yes')]

# Convert the relevant columns to a Series for better readability
outliers_series = pd.Series({
    'Customers with negative balance who made a deposit': negative_balance_with_deposit.shape[0]
})

print("Possible Outliers:")
print(outliers_series)
# Out:
# Possible Outliers:
# Customers with negative balance who made a deposit    0
# dtype: int64

# %%
df.head()
# Out:
#    age            job  balance housing loan    contact month  campaign  pdays  \
# 0   55         admin.     1662      no   no   cellular   jun         2     -1
# 1   39  self-employed     3058     yes  yes   cellular   apr         3     -1
# 2   51         admin.     3025      no   no   cellular   may         1    352
# 3   38       services      -87     yes   no   cellular   may         1     -1
# 4   36      housemaid      205     yes   no  telephone   nov         4     -1
#
#   poutcome deposit age_range
# 0  unknown     yes       56+
# 1  unknown     yes     36-45
# 2    other     yes     46-55
# 3  unknown      no     36-45
# 4  unknown      no     36-45

# %%
# Find customers with negative pdays and who subscribed
negative_pdays = df[(df['pdays'] < 0) & (df['deposit'] == 'yes')]

# Output the number of such customers
print("Number of customers with negative pdays who subscribed:", negative_pdays.shape[0])

# Show sample of these entries to understand the issue
print(negative_pdays[['pdays', 'deposit']].head())
# Out:
# Number of customers with negative pdays who subscribed: 2371
#     pdays deposit
# 0      -1     yes
# 1      -1     yes
# 6      -1     yes
# 11     -1     yes
# 13     -1     yes

# %% [markdown]
# There is unexpected problem to change the negative values in pdays, therefore since the negative values are only -1, any pdays with value of -1 is changed to 0 first

# %%
# Correct negative pdays values by setting them to NaN or another appropriate value
df.loc[df['pdays'] < 0, 'pdays'] = None

# %%
print(df['pdays'].isna().sum())
# Out:
# 0

# %%
df['pdays'].fillna(1, inplace=True)
print(df['pdays'].isna().sum())
# Out:
# 0

# %%
df.head()
# Out:
#    age            job  balance housing loan    contact month  campaign  pdays  \
# 0   55         admin.     1662      no   no   cellular   jun         2     -1
# 1   39  self-employed     3058     yes  yes   cellular   apr         3     -1
# 2   51         admin.     3025      no   no   cellular   may         1    352
# 3   38       services      -87     yes   no   cellular   may         1     -1
# 4   36      housemaid      205     yes   no  telephone   nov         4     -1
#
#   poutcome deposit age_range
# 0  unknown     yes       56+
# 1  unknown     yes     36-45
# 2    other     yes     46-55
# 3  unknown      no     36-45
# 4  unknown      no     36-45

# %%
# For column with categorical data
def analyze_categorical_column(bank_df, column_name, threshold_percentage=1.0):
    """
    Analyzes the frequency of categories in a categorical column and identifies rare categories.
    
    :param df: DataFrame containing the data
    :param column_name: Column name to analyze
    :param threshold_percentage: Threshold percentage to identify rare categories
    :return: Frequency counts, percentages, and rare categories
    """
    # Count frequency of each category
    freq_counts = bank_df[column_name].value_counts()
    
    # Calculate percentage of each category
    percentage = (freq_counts / len(bank_df)) * 100
    
    # Identify rare categories based on the threshold percentage
    rare_categories = percentage[percentage < threshold_percentage].index.tolist()
    
    return freq_counts, percentage, rare_categories

# List of categorical columns to analyze
categorical_columns = ['job', 'housing', 'loan', 'contact', 'month', 'poutcome']

# Analyze each categorical column
for col in categorical_columns:
    freq_counts, percentage, rare_categories = analyze_categorical_column(bank_df, col)
    print(f"Column: {col}")
    print(f"Frequency Counts:\n{freq_counts}\n")
    print(f"Percentage:\n{percentage}\n")
    print(f"Rare Categories (less than threshold): {rare_categories}\n")
# Out:
# Column: job
# Frequency Counts:
# job
# management       1789
# blue-collar      1343
# technician       1289
# admin.            936
# services          658
# retired           540
# self-employed     280
# unemployed        249
# student           247
# entrepreneur      236
# housemaid         184
# unknown            54
# Name: count, dtype: int64
#
# Percentage:
# job
# management       22.921204
# blue-collar      17.206919
# technician       16.515054
# admin.           11.992313
# services          8.430493
# retired           6.918642
# self-employed     3.587444
# unemployed        3.190263
# student           3.164638
# entrepreneur      3.023703
# housemaid         2.357463
# unknown           0.691864
# Name: count, dtype: float64
#
# Rare Categories (less than threshold): ['unknown']
#
# Column: housing
# Frequency Counts:
# housing
# no     4136
# yes    3669
# Name: count, dtype: int64
#
# Percentage:
# housing
# no     52.991672
# yes    47.008328
# ...

# %%
# Frequency count
job_counts = bank_df['job'].value_counts()

# categories with fewer than 100 occurrences)
threshold = 100

# Find rare categories
rare_jobs = job_counts[job_counts < threshold].index
rare_jobs
# Out:
# Index(['unknown'], dtype='object', name='job')

# %%
month_counts = bank_df['month'].value_counts()

# categories with fewer than 100 occurrences)
threshold = 100

# Find rare months
rare_months = month_counts[month_counts < threshold].index
rare_months
# Out:
# Index(['dec'], dtype='object', name='month')

# %% [markdown]
# From here, it is shown that there are outliers in the job column, and the month column. However, since the data here is considered as categorical, it is necessary to handle it according to the context. Here, it is understandable that perhaps the customer did not specify their job, or in december, there are only few that make the deposit, so the outlier will be leaved as it is.

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**

# %%
subscribed_customers = df[df['deposit'] == 'yes']

# Frequency counts of job categories for subscribed customers
job_counts_subscribed = subscribed_customers['job'].value_counts()

# Plotting the distribution
plt.figure(figsize=(12, 8))
job_counts_subscribed.plot(kind='bar', color='skyblue')
plt.title('Distribution of Job Categories Among Subscribed Customers')
plt.xlabel('Job')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Here, job categories management have the most frequency among the subscribed customer. It is understandable since management often possesed more salary, which lead to possessing more buying power, so they can afford term deposits.

# %% [markdown]
# Checking data distribution using histogram

# %%
# Define bins for balance
bins = [0, 1000, 5000, 10000, 20000, 50000, 100000]
labels = ['0-1k', '1k-5k', '5k-10k', '10k-20k', '20k-50k', '50k-100k']
subscribed_customers['balance_binned'] = pd.cut(subscribed_customers['balance'], bins=bins, labels=labels, right=False)

# Frequency counts of binned balance categories
balance_counts_subscribed = subscribed_customers['balance_binned'].value_counts().sort_index()

# Plotting the distribution
plt.figure(figsize=(12, 8))
balance_counts_subscribed.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of Binned Balance Among Subscribed Customers')
plt.xlabel('Balance Range')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
plt.show()

# %% [markdown]
# Here can see that people with higher buying power have less frequency of making subscription. However, it is necessary to note that these people have more access because they have more buying power, so there could be other factors that affect the little frequency of making subscription. But it is still understandable that the two lowest balance range have more frequency of making subcription, because of several factors such a limited option of investment product accessible by their buying power, their goals for saving, lifestyle, and etc. It is hard to predict precisely with just histogram

# %%
# Define bins for age
age_bins = [18, 30, 40, 50, 60, 70, 80, 90, 100]  
age_labels = ['18-29', '30-39', '40-49', '50-59', '60-69', '70-79','80-99','99+']

# Create a new column with binned age categories
subscribed_customers['age_binned'] = pd.cut(subscribed_customers['age'], bins=age_bins, labels=age_labels, right=False)

# %%
# Frequency counts of binned age categories
age_counts_subscribed = subscribed_customers['age_binned'].value_counts().sort_index()
bars = age_counts_subscribed.plot(kind='bar', color='skyblue', edgecolor='black')

# Plotting the distribution
for bar in bars.patches:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # x position
        height,  # y position
        f'{int(height)}',  # value text
        ha='center',  # horizontal alignment
        va='bottom'  # vertical alignment
    )

# %% [markdown]
# Here we can see that the age group of 30-39 dominates the proportion of the subscribes, followed by age groups of 40-49. It is understandable since in those age, people tend to choose investment products with low risk (stable). The third place surprisingly is taken by people with age group 18-29. It is understandable because in this era, a lot of young people already financially literated, however with limited buying power and their investing behaviour (where young people prefer more risky investment products), it is understandable that it gots only the third position.

# %%
subscribed_customers = df[df['deposit'] == 'yes']

# Frequency counts of job categories for subscribed customers
housing_counts_subscribed = subscribed_customers['housing'].value_counts()

# Plotting the distribution
plt.figure(figsize=(12, 8))
housing_counts_subscribed.plot(kind='bar', color='skyblue')
plt.title('Distribution of Housing Among Subscribed Customers')
plt.xlabel('Housing')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This show that among the subscribers, most of them have no housing already. It is understandable because term deposits is an investment products, and people who have no housing have more goals to achieved by saving (for instance, to obtain housing)

# %%
subscribed_customers = df[df['deposit'] == 'yes']

# Frequency counts of job categories for subscribed customers
loan_counts = subscribed_customers['loan'].value_counts()

# Plotting the distribution
plt.figure(figsize=(12, 8))
loan_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Loan Among Subscribed Customers')
plt.xlabel('Loan')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# It is understandable that the subscriber dominated by people who possess no loan, because term deposits cannot be withdrawn instantly, and people with no loan have more stable economy to afford subscribing term deposits.

# %% [markdown]
# Therefore, from the EDA here are the factors that could influence a customer to subscribe:
# 1. Balance (Buying Power)

# %% [markdown]
# # **5. Feature Engineering**

# %% [markdown]
# ## **5.1. Data Transformation**

# %%
df.head()
# Out:
#    age            job  balance housing loan    contact month  campaign  pdays  \
# 0   55         admin.     1662      no   no   cellular   jun         2    NaN
# 1   39  self-employed     3058     yes  yes   cellular   apr         3    NaN
# 2   51         admin.     3025      no   no   cellular   may         1  352.0
# 3   38       services      -87     yes   no   cellular   may         1    NaN
# 4   36      housemaid      205     yes   no  telephone   nov         4    NaN
#
#   poutcome deposit age_range
# 0  unknown     yes       56+
# 1  unknown     yes     36-45
# 2    other     yes     46-55
# 3  unknown      no     36-45
# 4  unknown      no     36-45

# %% [markdown]
# ## **5.2. Importing Additional Library**

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import make_scorer, fbeta_score, accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier, StackingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier

# %% [markdown]
# ## **5.3. Define Features, Targets, and Encoder**

# %%
categorical_features = ['job', 'housing', 'loan', 'contact', 'month', 'poutcome']
numerical_features = ['age', 'balance', 'campaign', 'pdays']
target = 'deposit'
# Label encode the target variable
one_hot_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
label_encoder = LabelEncoder()

# %% [markdown]
# ## **5.4. Normalization**

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler())
        ]), numerical_features),
        ('cat', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
            ('onehot', one_hot_encoder)
        ]), categorical_features)
    ]
)

# %% [markdown]
# ## **5.5. Data Splitting**

# %%
X = df.drop(columns=[target])
y = df[target]
y_encoded = label_encoder.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %% [markdown]
# The data split into 80:20 ratio for training and testing. Splitting the data allows us to evaluate how well the model generalizes to unseen data. By training the model on one subset (training set) and testing it on another (testing set), we can get an estimate of the model's performance on new data.

# %%
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', RandomForestClassifier(random_state=42))
])

# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)

# Predict on the test data
y_pred = pipeline.predict(X_test)

# %% [markdown]
# # **6. Model Selection and Training**

# %% [markdown]
# ## **6.1. Defining Models for Benchmarking**

# %% [markdown]
# Here several model is developed to figure out which models is the most appropriate for our objectives

# %% [markdown]
# Initialize several classification model to understand which is the best model to be used

# %%
# Base models
logreg = LogisticRegression(solver='liblinear', random_state=42)
knn = KNeighborsClassifier()
dtree = DecisionTreeClassifier(random_state=42)

# Ensemble models - Stacking
sc = StackingClassifier(estimators=[
    ('dtree', dtree),
    ('knn', knn),
    ('lr', logreg)
])

# Ensemble models - Soft Voting
vc = VotingClassifier(estimators=[
    ('dtree', dtree),
    ('knn', knn),
    ('lr', logreg)
], voting='soft')

# Ensemble models - Boosting
ada = AdaBoostClassifier(random_state=42)
gbc = GradientBoostingClassifier(random_state=42)
xgb = XGBClassifier(random_state=42, verbosity=0)

# Ensemble models - Bagging
rf = RandomForestClassifier(random_state=42)

# List of models 
models = [
    ('Logistic Regression', logreg),
    ('KNN', knn),
    ('Decision Tree', dtree),
    ('Stacking Classifier', sc),
    ('Voting Classifier', vc),
    ('AdaBoost', ada),
    ('Gradient Boosting', gbc),
    ('XGBoost', xgb),
    ('Random Forest', rf)
]

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)
results = {}

for name, model in models:
    # Create a pipeline for each model
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('model', model)
    ])
    
    # Perform cross-validation
    model_cv = cross_val_score(pipeline, X_train, y_train, cv=5, scoring=f2_scorer, error_score='raise')
    
    # Store the mean score
    results[name] = model_cv.mean()

# Output the results
for name, score in results.items():
    print(f"{name}: {score:.4f}")
# Out:
# Logistic Regression: 0.5994
# KNN: 0.6184
# Decision Tree: 0.6251
# Stacking Classifier: 0.6257
# Voting Classifier: 0.6419
# AdaBoost: 0.6335
# Gradient Boosting: 0.6345
# XGBoost: 0.6472
# Random Forest: 0.6527

# %% [markdown]
# ## **6.2. Finding the Best Model**

# %% [markdown]
# It shown above F2 score is used to determine the best model due to one of the objectives is to identify all potential subscribers (i.e., high recall). Here the models will be measured with other metrics to solidify the justification of the choosen model.

# %%
best_model_name = max(results, key=results.get)
best_model = [model for model in models if model[0] == best_model_name][0][1]

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', best_model)
])

pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# Print evaluation metrics for the best model
print(f"Best Model: {best_model_name}")
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Classification Report:\n{classification_report(y_test, y_pred, target_names=label_encoder.classes_)}")
# Out:
# Best Model: Random Forest
# Accuracy: 0.7130044843049327
# Classification Report:
#               precision    recall  f1-score   support
#
#           no       0.71      0.75      0.73       795
#          yes       0.72      0.67      0.70       766
#
#     accuracy                           0.71      1561
#    macro avg       0.71      0.71      0.71      1561
# weighted avg       0.71      0.71      0.71      1561

# %% [markdown]
# Here is shown the best model is Random Forest, using other metrics such as accuracy

# %% [markdown]
# # **7. Model Evaluation**

# %% [markdown]
# ## **7.1. Implementing Best Model**

# %% [markdown]
# Lets look into Random Forest Classifier Again

# %%
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', RandomForestClassifier(n_estimators=100, random_state=42))
])
# Fit the pipeline on training data
pipeline.fit(X_train, y_train)

# Predict on the test data
y_pred = pipeline.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)


print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.7130044843049327
# Confusion Matrix:
#  [[596 199]
#  [249 517]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.75      0.73       795
#            1       0.72      0.67      0.70       766
#
#     accuracy                           0.71      1561
#    macro avg       0.71      0.71      0.71      1561
# weighted avg       0.71      0.71      0.71      1561

# %% [markdown]
# ## **7.2. Interpretation of the result**

# %% [markdown]
# 1. Accuracy:
# The model correctly predict whether a customer will subscribe to a term deposit approximately 71% of the time.
# 2. Confusion Matrix:
#     According to the confusion matrix, The model correctly predict 'no' for 596 who did not subscribe.
#     <br>
#     The model inccorectly  predicted 'yes' for 199 customers who did not subscribe
#     <br>
#     The model inccorectly predicted 'no' for 249 customers who did subscribe
#     <br>
#     The model predicted 'yes' for 517 customers who did subscribe. These are the correctly targeted for potential marketing campagin
#     <br>
#     Recall for 'yes' (0.67): This indicates that the model is reasonably good at identifying customers who are likely to subscribe, though there’s room for improvement.
#     <br>
#     Precision for 'yes' (0.72): This shows that among the customers predicted to subscribe, a fair number are true subscribers, but there are still some false positives
# 3. Classification Report:
# Precision:
# <br>
# For 'no': 0.71. Out of all instances where the model predicted 'no', 71% were actually 'no' (i.e., the model correctly identified 71% of the 'no' predictions).
# <br>
# For 'yes': 0.72. Out of all instances where the model predicted 'yes', 72% were actually 'yes' (i.e., the model correctly identified 72% of the 'yes' predictions).
# <br>
# Recall:
# <br>
# For 'no': 0.75 Of all actual 'no' instances, 75% were correctly identified by the model (i.e., the model found 75% of all the actual 'no' cases).
# For 'yes': 0.67 Of all actual 'yes' instances, 67% were correctly identified by the model (i.e., the model found 67% of all the actual 'yes' cases).
# F1-Score:
# For 'no': 0.73 This combines the precision and recall for 'no' into a single metric, reflecting the balance between them. A higher F1-Score (closer to 1.0) indicates a better balance between precision and recall.
# For 'yes': 0.70 This combines the precision and recall for 'yes' into a single metric, reflecting the balance between them. A higher F1-Score (closer to 1.0) indicates a better balance between precision and recall.

# %% [markdown]
# ## **7.3. Adjustment**

# %% [markdown]
# Here, To explore several hyperparameter to improve the result

# %%
from sklearn.model_selection import GridSearchCV
# Define the parameter grid
param_grid = {
    'classifier__n_estimators': [50, 100, 200],
    'classifier__max_depth': [None, 10, 20, 30],
    'classifier__min_samples_split': [2, 5, 10],
    'classifier__min_samples_leaf': [1, 2, 4],
    'classifier__max_features': ['auto', 'sqrt', 'log2'],
    'classifier__bootstrap': [True, False]
}

# Initialize Grid Search
grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# Fit Grid Search to the data
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Predict and evaluate
y_pred = grid_search.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Best Parameters:", best_params)
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# Best Parameters: {'classifier__bootstrap': False, 'classifier__max_depth': 20, 'classifier__max_features': 'log2', 'classifier__min_samples_leaf': 2, 'classifier__min_samples_split': 10, 'classifier__n_estimators': 50}
# Accuracy: 0.7360666239590007
# Confusion Matrix:
#  [[651 144]
#  [268 498]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.82      0.76       795
#            1       0.78      0.65      0.71       766
#
#     accuracy                           0.74      1561
#    macro avg       0.74      0.73      0.73      1561
# weighted avg       0.74      0.74      0.73      1561

# %% [markdown]
# Performance Comparison
# <br>
# - Accuracy: 73.6% (New) | 71.3% (Previous)
# <br>
# - Confusion Matrix:
# <br>
# - True Negatives: 651 (New) | 596 (Previous)
# <br>
# - False Positives: 144 (New) | 199 (Previous)
# <br>
# - False Negatives: 268 (New) | 249 (Previous)
# <br>
# - True Positives: 498 (New) | 517 (Previous)
# <br>
# - Classification Report:
# <br>
# - Precision for 'no': 0.71 (New) | 0.71 (Previous)
# <br>
# - Precision for 'yes': 0.78 (New) | 0.72 (Previous)
# <br>
# - Recall for 'no': 0.82 (New) | 0.75 (Previous)
# <br>
# - Recall for 'yes': 0.65 (New) | 0.67 (Previous)
# <br>
# - F1-Score for 'no': 0.76 (New) | 0.73 (Previous)
# <br>
# - F1-Score for 'yes': 0.71 (New) | 0.70 (Previous)
# <br>

# %% [markdown]
# - The hyperparameters selected through GridSearchCV for the RandomForestClassifier led to notable improvements in model performance. With an accuracy of 73.6%, the model now more effectively predicts customer subscriptions, correctly identifying 'no' for 651 customers and 'yes' for 498 customers, while also reducing false positives and negatives compared to previous configurations.
# <br>
# - The chosen parameters, including fewer trees and specific depth and feature considerations, optimized the balance between precision and recall, achieving higher overall precision for both classes and a better F1-Score, thus demonstrating enhanced generalization and predictive accuracy.

# %%
importances = pipeline.named_steps['model'].feature_importances_
# Get one-hot encoded feature names
onehot_feature_names = pipeline.named_steps['preprocessor'].transformers_[1][1].named_steps['onehot'].get_feature_names_out(categorical_features)

# Combine numerical features with one-hot encoded feature names
all_feature_names = numerical_features + onehot_feature_names.tolist()

# Create a DataFrame for feature importances
feature_importance_df = pd.DataFrame({'Feature': all_feature_names, 'Importance': importances})

# Sort features by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

feature_importance_df
# Out:
#               Feature  Importance
# 1             balance    0.244776
# 0                 age    0.193479
# 2            campaign    0.087995
# 3               pdays    0.048770
# 37   poutcome_success    0.038667
# 20   contact_cellular    0.027402
# 22    contact_unknown    0.027251
# 38   poutcome_unknown    0.020654
# 8      job_management    0.016801
# 5     job_blue-collar    0.016292
# 16         housing_no    0.015696
# 17        housing_yes    0.015470
# 13     job_technician    0.015295
# 23          month_apr    0.015132
# 31          month_may    0.014223
# 4          job_admin.    0.013762
# 24          month_aug    0.013684
# 29          month_jun    0.012862
# 28          month_jul    0.012101
# 32          month_nov    0.011979
# 11       job_services    0.011157
# 30          month_mar    0.010909
# 19           loan_yes    0.010661
# 33          month_oct    0.010257
# 18            loan_no    0.010080
# 26          month_feb    0.009458
# ...

# %%
# feature importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance in the Random Forest Model')
plt.show()

# %% [markdown]
# In the graphic shown below, the total amount of balance is the most important feature that is used to develop the best model. This make sense, because buying power of a person also determine whether they have money to invest (through the term deposit) or not. By subscribing for a term deposit, the asset of the person become less liquid, which can only be afforded by people who have buying power which determine by the balance in their account.

# %%
from sklearn.metrics import roc_curve, roc_auc_score
# Predict probabilities
y_prob = pipeline.predict_proba(X_test)[:, 1]

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = roc_auc_score(y_test, y_prob)

# Plot ROC curve
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Curve Position: The ROC curve is well above the diagonal line, which means the model effectively differentiates between the positive and negative classes.
# <br>
# AUC (Area Under Curves)= 0.78: This tells us that there’s a 78% chance that the model will correctly rank a randomly chosen positive instance higher than a randomly chosen negative instance.

# %% [markdown]
# # **8. Cost Benefit Analysis**

# %% [markdown]
# ### **8.1. Cost-Benefit Analysis for Term Deposit Subscription Model**

# %% [markdown]
# **Objective:**
# <br>
# Evaluate the performance and financial impact of a machine learning model predicting term deposit subscriptions, using provided metrics and assumptions.
# <br><br>
# **Without the Model:**
# <br>
# The company continues its current marketing strategy without targeting customers who are likely to subscribe based on the model's predictions.
# The baseline conversion rate is 47.8%, indicating the percentage of customers who would subscribe under the current strategy.
# <br><br>
# **Model Performance:**
# <br>
# Accuracy of Model: 73.6%
# <br>
# True Positive Rate (Recall for 'subscribed'): 67.5%
# <br>
# False Positive Rate: 25.0%
# <br>
# Predicted Conversion Rate: 45.9%
# <br>
# Actual Conversion Rate (Baseline): 47.8%
# <br>

# %%
# Predict probabilities
y_prob = pipeline.predict_proba(X_test)[:, 1]

# Predict binary outcomes based on a threshold
y_pred = (y_prob > 0.5).astype(int)  
y_test_series = pd.Series(y_test)
y_pred_series = pd.Series(y_pred)

# Calculate conversion rate
conversion_rate = y_test_series.value_counts(normalize=True).get(1, 0)  # Actual positive rate
predicted_conversion_rate = y_pred_series.value_counts(normalize=True).get(1, 0)  # Predicted positive rate

print(f"Actual Conversion Rate: {conversion_rate:.2f}")
print(f"Predicted Conversion Rate: {predicted_conversion_rate:.2f}")
# Out:
# Actual Conversion Rate: 0.49
# Predicted Conversion Rate: 0.46

# %%
from sklearn.metrics import recall_score
# Calculate true positive rate (recall for 'yes')
recall_yes = recall_score(y_test, y_pred, pos_label=1)

# Calculate false positive rate
false_positive_rate = 1 - recall_score(y_test, y_pred, pos_label=0)

# Calculate costs
cost_per_false_positive = 100  # Example value
cost_per_false_negative = 50  # Example value
total_cost_false_positives = false_positive_rate * cost_per_false_positive * len(y_test)
total_cost_false_negatives = (1 - recall_yes) * cost_per_false_negative * len(y_test)

# Calculate expected revenue
revenue_per_correct_prediction = 200  # Example value
total_revenue = (recall_yes * len(y_test) * revenue_per_correct_prediction)

# Calculate ROI
roi = (total_revenue - (total_cost_false_positives + total_cost_false_negatives)) / (total_cost_false_positives + total_cost_false_negatives) * 100

print("Conversion Rate:", conversion_rate)
print("Predicted Conversion Rate:", predicted_conversion_rate)
print("True Positive Rate (Recall for 'yes'):", recall_yes)
print("False Positive Rate:", false_positive_rate)
print("Total Cost of False Positives:", total_cost_false_positives)
print("Total Cost of False Negatives:", total_cost_false_negatives)
print("Expected ROI:", roi ,"%")
# Out:
# Conversion Rate: 0.4907110826393338
# Predicted Conversion Rate: 0.458680333119795
# True Positive Rate (Recall for 'yes'): 0.674934725848564
# False Positive Rate: 0.2503144654088051
# Total Cost of False Positives: 39074.08805031447
# Total Cost of False Negatives: 25371.34464751958
# Expected ROI: 226.9659502449172 %

# %%
# Calculate the baseline conversion rate
total_customers = len(df)  # Total number of customers
conversions = df['deposit'].value_counts().get('yes', 0)  # Total number of conversions (subscribed to deposit)

# Convert to percentage
baseline_conversion_rate = conversions / total_customers

print("Baseline Conversion Rate: {:.2f}%".format(baseline_conversion_rate * 100))

# Assumption values
cost_per_false_positive = 100  # Example value
cost_per_false_negative = 50  # Example value
revenue_per_correct_prediction = 200  # Example value

# Calculate expected subscribers
expected_subscribers = baseline_conversion_rate * total_customers

# The cost associated with false positives might include marketing expenses spent on targeting these customers who eventually do not convert into a subscription
total_false_positives = (1 - baseline_conversion_rate) * total_customers
total_cost_false_positives = total_false_positives * cost_per_false_positive

# Calculate total false negatives (lost revenue from not targeting customer who could have been subscribe) and cost 
total_false_negatives = (1 - baseline_conversion_rate) * total_customers
total_cost_false_negatives = total_false_negatives * cost_per_false_negative

# Calculate total revenue
total_revenue = expected_subscribers * revenue_per_correct_prediction

# Calculate total cost without model
total_cost_without_model = total_cost_false_positives + total_cost_false_negatives

# Calculate ROI without model
roi_without_model = (total_revenue - total_cost_without_model) / total_cost_without_model * 100

# Print results
print(f"Total Cost Without Model: ${total_cost_without_model:.2f}")
print(f"Total Revenue Without Model: ${total_revenue:.2f}")
print(f"ROI Without Model: {roi_without_model:.2f}%")
# Out:
# Baseline Conversion Rate: 47.79%
# Total Cost Without Model: $611250.00
# Total Revenue Without Model: $746000.00
# ROI Without Model: 22.04%

# %% [markdown]
# ## **8.2. Key Findings**

# %% [markdown]
# **Comparison of Conversion Rates**
# | Metric                         | Value      |
# |--------------------------------|------------|
# | Baseline Conversion Rate       | 47.79%     |
# | Model Predicted Conversion Rate| 45.87%     |
#
# **Cost Analysis**
# **Without Model**
# | Cost Component                | Amount         |
# |-------------------------------|----------------|
# | Total Cost of False Positives | $17,869,500    |
# | Total Cost of False Negatives | $25,371,344.65 |
# | Total Revenue                 | $74,600,000    |
# | ROI                           | -517.47%       |
#
# **With Model**
# | Cost Component                | Amount         |
# |-------------------------------|----------------|
# | Total Cost of False Positives | $39,074.08     |
# | Total Cost of False Negatives | $25,371.34     |
# | Total Revenue                 | $200,000       |
# | ROI                           | 226.97%        |
#
# **Cost Efficiency**
# - The use of the machine learning model reduces the costs associated with false positives and false negatives.
# - The model directs marketing efforts more efficiently, saving on unnecessary costs and increasing revenue from correct predictions.

# %% [markdown]
# This shows that is highly effective, significantly increasing ROI (Return of Investment) compared to the costs associated with false predictions.
# <br>
# Financial Impact:
# - The model not only offsets the costs of false predictions but also generates substantial additional revenue, demonstrating a strong return on investment (assumed that revenue_per_correct_prediction = 200 ). This occurred because Cost of False Negatives (not predicting a subscriber) could be decreased.
# <br>
# - False negative represents the lost revenue opportunity when a potential subscriber is not identified by the model.
# <br>
# Cost of False positive reflects the expense associated with targeting a customer who does not end up subscribing, such as marketing costs, which is shown that with the best model, it is lower than without implementing the best model.

# %% [markdown]
# ## **8.3. Conclusion**

# %% [markdown]
# 1. Without the model, the cost associated with false positives (customers incorrectly predicted as subscribers) is extremely high at $17,869,500. This is because, in the absence of a model, many non-subscribers are incorrectly targeted, and many subscribers are not identified.
# <br>
# 2. Higher Baseline Conversion Rate: The higher baseline conversion rate of 47.79% reflects a broader and less accurate approach to identifying potential subscribers. Without a predictive model, the company might be overly optimistic in its estimations, resulting in higher apparent conversion rates.
# Decreased Revenue Without Model: Despite the higher conversion rate, the revenue is actually decreased because the costs associated with false positives and false negatives are exceedingly high. The company is spending more on targeting incorrect customers and missing out on actual subscribers, leading to a net loss.
# <br>
# 3. Implementing the best ML model leads to more accurate predictions, reducing unnecessary costs associated with incorrect targeting and improving overall profitability despite a slightly lower conversion rate.

# %% [markdown]
# ## **8.4. Recommendations**

# %% [markdown]
# - Implement the ML model to enhance prediction accuracy and reduce costs. By Utilizing the model's predictions to focus on potential subscribers, budget can be allocate accurately and reducing the resources on non-subscribers.
# <br>
# - Regularly evaluate the model's performance and update it with new data to maintain accuracy and effectiveness. The model's predictions will become more accurate when the models keep evaluated.
# Experiment with different thresholds for the prediction probability to find an optimal balance between precision and recall.
